# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
#possible new feature: #words in response that match with question

# %%
#read data
data = pd.read_csv("p2_train.csv")
data.head()
# Out:
#   thread_id question_id response_id no_turn_q_id quoted_q_id  \
# 0    2rnfn0     cnij1d3     cnj3fl4        n_676       q_102
# 1    3htb3d     cuau7nc     cuaupyz       n_7406      q_1087
# 2    2ffph1     ck8sgpm     ck8ssbg      n_87393     q_11524
# 3    2qix6r     cn6kszk     cn6l15g       n_8390      q_1155
# 4    2f7hxq     ck6q9m4     ck6qnd5      n_89812     q_11886
#
#                                            precedent  \
# 0  The most dangerous <&quot;>neighborhood<&quot;...
# 1                                      Riiiiiiiight.
# 2                                       Time? Money?
# 3   &gt; And there is no connotation, look up sta...
# 4                 What the fuck does that even mean?
#
#                                             question  \
# 0       Should all the blacks in the state move out?
# 1  So, correct me if I'm wrong, but what you're s...
# 2                        What about the all country?
# 3  And men commit more crimes than women, ages 20...
# ...

# %%
#filter out data to present only the relevant columns: question_id, response_id, question, response, type
relevant_columns = "question_id response_id question response type".split(" ")
data = data[relevant_columns]
data.head()
# Out:
#   question_id response_id                                           question  \
# 0     cnij1d3     cnj3fl4       Should all the blacks in the state move out?
# 1     cuau7nc     cuaupyz  So, correct me if I'm wrong, but what you're s...
# 2     ck8sgpm     ck8ssbg                        What about the all country?
# 3     cn6kszk     cn6l15g  And men commit more crimes than women, ages 20...
# 4     ck6q9m4     ck6qnd5                         How is that Quinn's fault?
#
#                                             response      type
# 0  I can't make decisions for other people. But I...  answered
# 1        \nGive me an example of another depiction.   attacked
# 2  And how is a critic going to help you do that ...  attacked
# 3  It's like that, but citizens have an entitleme...  answered
# 4  It's not Quinn's fault. But for defending Quin...  answered

# %%
#
